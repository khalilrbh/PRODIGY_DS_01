# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#reading the data from csv file
file_path="C:/Users/Lenovo/Desktop/prodigy_inter/population_by_age_group.csv"
data=pd.read_csv(file_path)

#previewing the first 5 records
print(data.head(5))

#previewing the last 5 records
print(data.tail(5))
# Out:
#           Country     Total      65+  25-64 years  15-24 years  5-14 years  \
# 0     Afghanistan  40099460   964016     12995277      8727160    10922454
# 1         Albania   2854710   463442      1527360       399113      323402
# 2         Algeria  44177964  2731079     21871300      6007614     8697129
# 3  American Samoa     45056     3088        22433         7141        8365
# 4         Andorra     79057    11499        48651         8570        7797
#
#    0-4 years
# 0    6490554
# 1     141393
# 2    4870841
# 3       4029
# 4       2540
#                Country     Total     65+  25-64 years  15-24 years  \
# 230  Wallis and Futuna     11654    1521         5767         1652
# 231     Western Sahara    565590   31718       314200        80572
# 232              Yemen  32981644  886890     12210659      6733620
# 233             Zambia  19473132  338628      6734346      3975624
# 234           Zimbabwe  15993525  537915      5572892      3342436
#
# ...

# %%
data.describe()
# Out:
#               Total           65+   25-64 years   15-24 years    5-14 years  \
# count  2.350000e+02  2.350000e+02  2.350000e+02  2.350000e+02  2.350000e+02
# mean   3.365653e+07  3.239456e+06  1.663291e+07  5.209602e+06  5.717213e+06
# std    1.359563e+08  1.459906e+07  7.266853e+07  2.062212e+07  2.107024e+07
# min    1.869000e+03  1.590000e+02  8.520000e+02  2.060000e+02  3.690000e+02
# 25%    4.266510e+05  3.347550e+04  2.388210e+05  6.762500e+04  6.795800e+04
# 50%    5.457165e+06  3.727000e+05  2.784971e+06  7.462240e+05  7.642670e+05
# 75%    2.183921e+07  1.534978e+06  9.579148e+06  3.715164e+06  4.494770e+06
# max    1.425894e+09  1.875015e+08  8.257142e+08  2.545856e+08  2.462618e+08
#
#           0-4 years
# count  2.350000e+02
# mean   2.857348e+06
# std    9.809743e+06
# min    1.450000e+02
# 25%    3.648400e+04
# 50%    4.123510e+05
# 75%    2.075203e+06
# max    1.153074e+08

# %%
data.isnull()
# Out:
#      Country  Total    65+  25-64 years  15-24 years  5-14 years  0-4 years
# 0      False  False  False        False        False       False      False
# 1      False  False  False        False        False       False      False
# 2      False  False  False        False        False       False      False
# 3      False  False  False        False        False       False      False
# 4      False  False  False        False        False       False      False
# ..       ...    ...    ...          ...          ...         ...        ...
# 230    False  False  False        False        False       False      False
# 231    False  False  False        False        False       False      False
# 232    False  False  False        False        False       False      False
# 233    False  False  False        False        False       False      False
# 234    False  False  False        False        False       False      False
#
# [235 rows x 7 columns]

# %%
data.shape
# Out:
# (235, 7)

# %%
data.info
# Out:
# <bound method DataFrame.info of                Country     Total      65+  25-64 years  15-24 years  \
# 0          Afghanistan  40099460   964016     12995277      8727160
# 1              Albania   2854710   463442      1527360       399113
# 2              Algeria  44177964  2731079     21871300      6007614
# 3       American Samoa     45056     3088        22433         7141
# 4              Andorra     79057    11499        48651         8570
# ..                 ...       ...      ...          ...          ...
# 230  Wallis and Futuna     11654     1521         5767         1652
# 231     Western Sahara    565590    31718       314200        80572
# 232              Yemen  32981644   886890     12210659      6733620
# 233             Zambia  19473132   338628      6734346      3975624
# 234           Zimbabwe  15993525   537915      5572892      3342436
#
#      5-14 years  0-4 years
# 0      10922454    6490554
# 1        323402     141393
# 2       8697129    4870841
# ...

# %%
data.dtypes
# Out:
# Country        object
# Total           int64
# 65+             int64
# 25-64 years     int64
# 15-24 years     int64
# 5-14 years      int64
# 0-4 years       int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Country', 'Total', '65+', '25-64 years', '15-24 years', '5-14 years',
#        '0-4 years'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum().any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# Country        0
# Total          0
# 65+            0
# 25-64 years    0
# 15-24 years    0
# 5-14 years     0
# 0-4 years      0
# dtype: int64

# %%
#sorting the data by population
sorted_data=data.sort_values(by='Total',ascending=False)

#finding the top 10 countries
top_10_countries=sorted_data.head(10)
print(top_10_countries[['Country','Total']])

top_10_country_name=top_10_countries['Country']
top_10_country_pop=top_10_countries['Total']
# Out:
#            Country       Total
# 42           China  1425893500
# 95           India  1407563900
# 223  United States   336997630
# 96       Indonesia   273753180
# 159       Pakistan   231402110
# 28          Brazil   214326220
# 152        Nigeria   213401330
# 16      Bangladesh   169356240
# 173         Russia   145102750
# 134         Mexico   126705140

# %%
#create the bar plot
plt.figure(figsize=(15,8))
sns.barplot(data=top_10_countries,y=top_10_country_name,x=top_10_country_pop,palette='viridis')

#add titles and labes
plt.title("Top 10 Countries by Total Population",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries",fontsize=10)

#rotate axis for better readability
plt.yticks(rotation=45)
plt.xticks(rotation=45)

#adjust layout
plt.tight_layout()
#show the plot
plt.show()

# %%
#sorting the data by population
sorted_data_asc=data.sort_values(by='Total',ascending=True)

#finding the top 10 countries
bot_10_countries=sorted_data_asc.head(10)
print(bot_10_countries[['Country','Total']])

bot_10_country_name=bot_10_countries['Country']
bot_10_country_pop=bot_10_countries['Total']
# Out:
#                        Country  Total
# 211                    Tokelau   1869
# 153                       Niue   1957
# 68            Falkland Islands   3786
# 140                 Montserrat   4438
# 175               Saint Helena   5428
# 179  Saint Pierre and Miquelon   5905
# 218                     Tuvalu  11229
# 230          Wallis and Futuna  11654
# 145                      Nauru  12533
# 6                     Anguilla  15779

# %%
#create the bar plot
plt.figure(figsize=(15,8))
sns.barplot(data=bot_10_countries,y=bot_10_country_name,x=bot_10_country_pop,palette='viridis')

#set titles and labels
plt.title("10 Countries with the least population",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries",fontsize=10)

#rotate axis for better readability
plt.yticks(rotation=45)
plt.xticks(rotation=45)

#adjust layout
plt.tight_layout()

#show the plot
plt.show()

# %%
#extract data by country name
India_data=pd.DataFrame(data[data['Country']=='India'])

#remove unnecessary columns
India_data=India_data.drop(columns=['Country','Total'])
print(India_data)
# Out:
#          65+  25-64 years  15-24 years  5-14 years  0-4 years
# 95  95749030    695659970    254585650   246261830  115307420

# %%
#create the bar plot
plt.figure(figsize=(15,8))
sns.barplot(data=India_data,palette='viridis')

#set titles and labels
plt.title("India Population",fontsize=10)
plt.xlabel('Age Range',fontsize=10)
plt.ylabel('Population',fontsize=10)

# Rotate axis labels for better readability
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#adjust the layout
plt.tight_layout()

#show the plot
plt.show()

# %%
#extract data by country name
Argentina_data=pd.DataFrame(data[data['Country']=='Argentina'])

#remove unnecessary columns
Argentina_data=Argentina_data.drop(columns=['Country','Total'])
print(Argentina_data)
# Out:
#        65+  25-64 years  15-24 years  5-14 years  0-4 years
# 8  5352580     22383468      6965561     7242438    3332743

# %%
#create the bar plot
plt.figure(figsize=(15,8))
sns.barplot(data=Argentina_data,palette='viridis')

#set titles and labels
plt.title("Argentina Population",fontsize=10)
plt.xlabel('Age Range',fontsize=10)
plt.ylabel('Population',fontsize=10)

# Rotate axis labels for better readability
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#adjust the layout
plt.tight_layout()

#show the plot
plt.show()
